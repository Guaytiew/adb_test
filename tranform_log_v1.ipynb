# %%
import pandas as pd
import numpy as np
import json

pd.set_option('display.max_colwidth', None)

# %%
# # https://stackoverflow.com/questions/72624920/how-do-i-export-pipeline-runtime-duration-to-csv
# from azure.mgmt.datafactory import DataFactoryManagementClient
# from azure.mgmt.datafactory.models import RunFilterParameters
# from azure.identity import DefaultAzureCredential, ClientSecretCredential
# from datetime import datetime, timedelta
# from pprint import pprint
# import logging

# # Set up logging
# logging.basicConfig(level=logging.DEBUG)

# # Authentication and client setup
# client_id = "218abebf-768e-4189-9ad4-f2fae2fc7915"
# client_secret = "Fn.8Q~5geWrWwjVnzYAoCiF34pWuyN2GMSB9Eag4"
# tenant_id = "209f121a-fbe4-4772-a6b7-e8c4360ab02f"

# # Authenticate
# credential = ClientSecretCredential(tenant_id, client_id, client_secret)
# # credential = DefaultAzureCredential()

# subscription_id = "e8dfd8f2-864b-49d4-9308-e0279475b474"
# resource_group_name = "dummy_group"
# data_factory_name = "dummyfactory"

# adf_client = DataFactoryManagementClient(credential, subscription_id)

# # Define time window for pipeline runs
# time_window_start = (datetime.now() - timedelta(days=1)).isoformat()
# time_window_end = datetime.now().isoformat()

# # Define filter parameters
# filter_parameters = RunFilterParameters(
#     last_updated_after=time_window_start,
#     last_updated_before=time_window_end
# )

# # List pipeline runs (it's required the pipeline id )
# # pipeline_runs = adf_client.activity_runs.query_by_pipeline_run(
# #     resource_group_name,
# #     data_factory_name,
# #     filter_parameters
# # )
# pipeline_runs = adf_client.pipeline_runs.query_by_factory(
#     resource_group_name,
#     data_factory_name,
#     filter_parameters = filter_parameters
# )

# # print('pipeline_runs: ', pipeline_runs)
# print('pipeline_runs:', pipeline_runs)

# for run in pipeline_runs.value:
#     print(f"Run ID: {run.run_id}, Status: {run.status}")
#     pprint(vars(run))
#     # print(run)

# %%
# df = pd.read_csv('D:/WisdomDEV-DF-01_Pipeline runs 30day.csv') # 'D:/WisdomDEV-DF-01_Pipeline runs1.csv'
df = pd.read_csv('C:/Users/Khlang-Thinnarat/Downloads/pipeline_timeline_input.csv')
df.head()
# Out:
#                    Pipeline name              Run start
# 0             01_Generate_paquet  7/30/2024, 5:30:36 PM  \
# 1           03_Reconcile_Mapping  7/30/2024, 5:23:09 PM
# 2  011_Mapping_Staging_to_Wisdom  7/30/2024, 5:14:26 PM
# 3     012_Mapping_Json_to_Wisdom  7/30/2024, 5:14:26 PM
# 4           01_Mapping_to_Wisdom  7/30/2024, 5:14:25 PM
#
#                  Run end Duration                          Triggered by
# 0                     --       7s                        Manual trigger  \
# 1  7/30/2024, 5:27:35 PM   4m 27s  6684475a-a5f3-4af0-b874-9eb4d7621abc
# 2  7/30/2024, 5:21:42 PM   7m 17s  9ab40b5f-1564-4a16-aa95-648b47b214a7
# 3  7/30/2024, 5:23:08 PM   8m 43s  75dea710-d36a-461e-9aee-a4dc9219420c
# 4  7/30/2024, 5:27:36 PM  13m 12s  0c700d04-3501-4074-90cb-074750b998ba
#
#         Status
# 0  In progress  \
# 1       Failed
# 2    Succeeded
# 3    Succeeded
# 4       Failed
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        Error
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        NaN  \
# 1                                                   Operation on target Reconcile_Module failed: Activity failed because an inner activity failed; Inner activity name: reconcile_application, Error: Databricks execution failed with error state: Terminated, error message: Workload failed, see run output for details. For more details please check the run page url: https://adb-7313697149820136.16.azuredatabricks.net/?o=7313697149820136#job/1038658689166809/run/32555573011374.
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        NaN
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        NaN
# 4  Operation on target 03_Reconcile_Mapping failed: Operation on target Reconcile_Module failed: Activity failed because an inner activity failed; Inner activity name: reconcile_application, Error: Databricks execution failed with error state: Terminated, error message: Workload failed, see run output for details. For more details please check the run page url: https://adb-7313697149820136.16.azuredatabricks.net/?o=7313697149820136#job/1038658689166809/run/32555573011374.
#
#               Run
# 0        Original  \
# 1        Original
# 2  Rerun (Latest)
# 3  Rerun (Latest)
# 4  Rerun (Latest)
#
#                                                                                                         Parameters
# 0                                                               {"source_name":"REFINED_DATA","date":"2024-07-30"}  \
# 1  {"source_schema_name":"PRE_WISDOM","target_schema_name":"dbo","cut_off_date":"2024-07-30","target_env":"QAS02"}
# 2  {"source_schema_name":"PRE_WISDOM","target_schema_name":"dbo","cut_off_date":"2024-07-30","target_env":"QAS02"}
# 3  {"source_schema_name":"PRE_WISDOM","target_schema_name":"dbo","cut_off_date":"2024-07-30","target_env":"QAS02"}
# 4  {"source_schema_name":"PRE_WISDOM","target_schema_name":"dbo","cut_off_date":"2024-07-30","target_env":"QAS02"}
#
#   Annotations                                Run ID
# 0          []  b874955f-d456-468a-87f6-cf2e2669912e
# 1          []  575d13d7-524d-4780-806c-b267501d853f
# 2          []  05a4d1ad-adaa-4b4b-bbf8-57e55debb06e
# 3          []  5a05ce29-5425-46dc-9000-c348ff3db97d
# 4          []  e636c2fc-9fee-43a5-ba0c-9864cc1615e7

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Pipeline name  100 non-null    object
#  1   Run start      100 non-null    object
#  2   Run end        100 non-null    object
#  3   Duration       100 non-null    object
#  4   Triggered by   100 non-null    object
#  5   Status         100 non-null    object
#  6   Error          15 non-null     object
#  7   Run            100 non-null    object
#  8   Parameters     91 non-null     object
#  9   Annotations    100 non-null    object
#  10  Run ID         100 non-null    object
# dtypes: object(11)
# memory usage: 8.7+ KB

# %%
df.columns
# Out:
# Index(['Pipeline name', 'Run start', 'Run end', 'Duration', 'Triggered by',
#        'Status', 'Error', 'Run', 'Parameters', 'Annotations', 'Run ID'],
#       dtype='object')

# %%
df['Pipeline name'].unique()
# Out:
# array(['01_Generate_paquet', '03_Reconcile_Mapping',
#        '011_Mapping_Staging_to_Wisdom', '012_Mapping_Json_to_Wisdom',
#        '01_Mapping_to_Wisdom', '01_create_delta_table',
#        '72_create_temp_table', 'HALF_SYSTEM_DEPLOYMENT',
#        '03_Reconcile_Migration', '02_Migrate_to_staging',
#        '00_Init_Migration', 'sp_migration_dalta_lake',
#        'fulload_migrate_delta_lake', 'update_delta_query',
#        'FULL_SYSTEM_DEPLOYMENT_HOT_FIXED'], dtype=object)

# %%
from datetime import timedelta
timedelta(minutes=5).total_seconds()
# Out:
# datetime.timedelta

# %%
keep_col = ['Pipeline name', 'Run start', 'Run end', 'Parameters']
terminate_pipeline = ['00_Init_Mapping', '00_Init_Migration'] # , '72_create_temp_table', 'fulload_migrate_delta_lake', 'update_delta_query'
exclude_status = ['In progress']
df2 = df.loc[~df['Pipeline name'].isin(terminate_pipeline) &
             ~df['Status'].isin(exclude_status),
               keep_col]

def extract_source_name(param):
    if isinstance(param, str):
        param_dict = json.loads(param)
        for key in ['source_name', 'schema_name', 'target_schema_name', 'source_schema_name']:
            if key in param_dict:
                return param_dict[key]
    return None
df2['source_name'] = df2['Parameters'].apply(lambda x: extract_source_name(x))
# df2['source_name']= df2['Parameters'].apply(
#     lambda x: json.loads(x).get('source_name')
#     or json.loads(x).get('schema_name')
#     or json.loads(x).get('target_schema_name')
#     or json.loads(x).get('source_schema_name')
#     or None if x == '' else x
# )
print(df2.to_markdown())
df2.drop(columns=['Parameters'], inplace=True)
# Out:
# |    | Pipeline name                    | Run start              | Run end                | Parameters                                                                                                      | source_name     |
# |---:|:---------------------------------|:-----------------------|:-----------------------|:----------------------------------------------------------------------------------------------------------------|:----------------|
# |  1 | 03_Reconcile_Mapping             | 7/30/2024, 5:23:09 PM  | 7/30/2024, 5:27:35 PM  | {"source_schema_name":"PRE_WISDOM","target_schema_name":"dbo","cut_off_date":"2024-07-30","target_env":"QAS02"} | dbo             |
# |  2 | 011_Mapping_Staging_to_Wisdom    | 7/30/2024, 5:14:26 PM  | 7/30/2024, 5:21:42 PM  | {"source_schema_name":"PRE_WISDOM","target_schema_name":"dbo","cut_off_date":"2024-07-30","target_env":"QAS02"} | dbo             |
# |  3 | 012_Mapping_Json_to_Wisdom       | 7/30/2024, 5:14:26 PM  | 7/30/2024, 5:23:08 PM  | {"source_schema_name":"PRE_WISDOM","target_schema_name":"dbo","cut_off_date":"2024-07-30","target_env":"QAS02"} | dbo             |
# |  4 | 01_Mapping_to_Wisdom             | 7/30/2024, 5:14:25 PM  | 7/30/2024, 5:27:36 PM  | {"source_schema_name":"PRE_WISDOM","target_schema_name":"dbo","cut_off_date":"2024-07-30","target_env":"QAS02"} | dbo             |
# |  5 | 01_create_delta_table            | 7/30/2024, 5:14:12 PM  | 7/30/2024, 5:14:22 PM  | {"schema_name":"dbo"}                                                                                           | dbo             |
# |  6 | 72_create_temp_table             | 7/30/2024, 5:13:46 PM  | 7/30/2024, 5:14:11 PM  | nan                                                                                                             |                 |
# |  7 | HALF_SYSTEM_DEPLOYMENT           | 7/30/2024, 5:13:45 PM  | 7/30/2024, 5:27:37 PM  | {"date":"2024-07-30","target_env":"QAS02","target_schema":"dbo","version_date":"2024-MM-DD"}                    |                 |
# |  8 | 72_create_temp_table             | 7/30/2024, 3:09:30 PM  | 7/30/2024, 3:10:01 PM  | nan                                                                                                             |                 |
# |  9 | HALF_SYSTEM_DEPLOYMENT           | 7/30/2024, 3:09:29 PM  | 7/30/2024, 3:10:02 PM  | {"date":"2024-07-30","target_env":"QAS02","target_schema":"dbo","version_date":"2024-MM-DD"}                    |                 |
# | 10 | 012_Mapping_Json_to_Wisdom       | 7/26/2024, 8:33:04 AM  | 7/26/2024, 10:20:24 AM | {"source_schema_name":"PRE_WISDOM","target_schema_name":"dbo","cut_off_date":"2024-07-26","target_env":"UAT02"} | dbo             |
# | 11 | 011_Mapping_Staging_to_Wisdom    | 7/26/2024, 8:33:04 AM  | 7/26/2024, 10:20:23 AM | {"source_schema_name":"PRE_WISDOM","target_schema_name":"dbo","cut_off_date":"2024-07-26","target_env":"UAT02"} | dbo             |
# | 12 | 01_Mapping_to_Wisdom             | 7/26/2024, 8:33:03 AM  | 7/26/2024, 10:20:24 AM | {"source_schema_name":"PRE_WISDOM","target_schema_name":"dbo","cut_off_date":"2024-07-26","target_env":"UAT02"} | dbo             |
# | 13 | 01_create_delta_table            | 7/26/2024, 7:12:31 AM  | 7/26/2024, 8:05:48 AM  | {"schema_name":"dbo"}                                                                                           | dbo             |
# | 14 | 72_create_temp_table             | 7/26/2024, 6:57:36 AM  | 7/26/2024, 7:09:38 AM  | nan                                                                                                             |                 |
# | 15 | 03_Reconcile_Migration           | 7/25/2024, 6:44:59 PM  | 7/25/2024, 6:52:37 PM  | {"source_name":"REFINED_DATA","cut_off_date":"2024-07-25","source_type":"parquet"}                              | REFINED_DATA    |
# | 16 | 02_Migrate_to_staging            | 7/25/2024, 5:39:47 PM  | 7/25/2024, 5:56:16 PM  | {"source_name":"REFINED_DATA","date":"2024-07-25"}                                                              | REFINED_DATA    |
# | 19 | sp_migration_dalta_lake          | 7/25/2024, 5:10:20 PM  | 7/25/2024, 5:11:13 PM  | {"schema_name":"REFINED_DATA"}                                                                                  | REFINED_DATA    |
# | 20 | 03_Reconcile_Migration           | 7/25/2024, 4:53:52 PM  | 7/25/2024, 4:55:44 PM  | {"source_name":"REFINED_DATA","cut_off_date":"2024-07-25","source_type":"parquet"}                              | REFINED_DATA    |
# | 21 | 02_Migrate_to_staging            | 7/25/2024, 4:51:31 PM  | 7/25/2024, 4:55:45 PM  | {"source_name":"REFINED_DATA","date":"2024-07-25"}                                                              | REFINED_DATA    |
# | 22 | 01_Generate_paquet               | 7/25/2024, 4:50:40 PM  | 7/25/2024, 4:55:46 PM  | {"source_name":"REFINED_DATA","date":"2024-07-25"}                                                              | REFINED_DATA    |
# | 23 | sp_migration_dalta_lake          | 7/25/2024, 4:26:50 PM  | 7/25/2024, 4:34:18 PM  | {"schema_name":"RGNWISE"}                                                                                       | RGNWISE         |
# | 24 | sp_migration_dalta_lake          | 7/25/2024, 3:57:12 PM  | 7/25/2024, 4:22:20 PM  | {"schema_name":"WELLVIEW_METRIC"}                                                                               | WELLVIEW_METRIC |
# | 25 | sp_migration_dalta_lake          | 7/25/2024, 3:52:04 PM  | 7/25/2024, 4:26:49 PM  | {"schema_name":"PWED"}                                                                                          | PWED            |
# | 26 | sp_migration_dalta_lake          | 7/25/2024, 3:52:04 PM  | 7/25/2024, 3:57:11 PM  | {"schema_name":"WISE_VIEW"}                                                                                     | WISE_VIEW       |
# | 27 | sp_migration_dalta_lake          | 7/25/2024, 3:52:04 PM  | 7/25/2024, 4:29:43 PM  | {"schema_name":"WISE"}                                                                                          | WISE            |
# | 28 | fulload_migrate_delta_lake       | 7/25/2024, 3:52:02 PM  | 7/25/2024, 4:34:20 PM  | nan                                                                                                             |                 |
# | 29 | sp_migration_dalta_lake          | 7/25/2024, 3:32:23 PM  | 7/25/2024, 3:51:50 PM  | {"schema_name":"WELLVIEW_METRIC"}                                                                               | WELLVIEW_METRIC |
# | 30 | sp_migration_dalta_lake          | 7/25/2024, 3:28:07 PM  | 7/25/2024, 3:52:23 PM  | {"schema_name":"PWED"}                                                                                          | PWED            |
# | 31 | sp_migration_dalta_lake          | 7/25/2024, 3:28:07 PM  | 7/25/2024, 3:50:48 PM  | {"schema_name":"WISE"}                                                                                          | WISE            |
# | 32 | sp_migration_dalta_lake          | 7/25/2024, 3:28:07 PM  | 7/25/2024, 3:32:22 PM  | {"schema_name":"WISE_VIEW"}                                                                                     | WISE_VIEW       |
# | 33 | fulload_migrate_delta_lake       | 7/25/2024, 3:28:04 PM  | 7/25/2024, 3:52:23 PM  | nan                                                                                                             |                 |
# | 34 | sp_migration_dalta_lake          | 7/25/2024, 3:07:58 PM  | 7/25/2024, 3:18:23 PM  | {"schema_name":"WISE"}                                                                                          | WISE            |
# | 35 | sp_migration_dalta_lake          | 7/25/2024, 2:42:02 PM  | 7/25/2024, 2:49:40 PM  | {"schema_name":"RGNWISE"}                                                                                       | RGNWISE         |
# | 36 | sp_migration_dalta_lake          | 7/25/2024, 2:34:21 PM  | 7/25/2024, 2:42:01 PM  | {"schema_name":"WISE_VIEW"}                                                                                     | WISE_VIEW       |
# | 37 | sp_migration_dalta_lake          | 7/25/2024, 2:34:21 PM  | 7/25/2024, 3:07:57 PM  | {"schema_name":"PWED"}                                                                                          | PWED            |
# | 38 | 01_create_delta_table            | 7/23/2024, 4:34:14 PM  | 7/23/2024, 4:52:57 PM  | {"schema_name":"dbo"}                                                                                           | dbo             |
# | 39 | 72_create_temp_table             | 7/23/2024, 4:22:24 PM  | 7/23/2024, 4:32:47 PM  | nan                                                                                                             |                 |
# | 40 | 03_Reconcile_Migration           | 7/23/2024, 1:53:46 PM  | 7/23/2024, 2:00:54 PM  | {"source_name":"REFINED_DATA","cut_off_date":"2024-07-23","source_type":"parquet"}                              | REFINED_DATA    |
# | 41 | 02_Migrate_to_staging            | 7/23/2024, 1:45:16 PM  | 7/23/2024, 2:00:55 PM  | {"source_name":"REFINED_DATA","date":"2024-07-23"}                                                              | REFINED_DATA    |
# | 44 | 03_Reconcile_Migration           | 7/23/2024, 1:07:29 PM  | 7/23/2024, 1:18:34 PM  | {"source_name":"REFINED_DATA","cut_off_date":"2024-07-23","source_type":"parquet"}                              | REFINED_DATA    |
# | 45 | 03_Reconcile_Migration           | 7/23/2024, 12:49:08 PM | 7/23/2024, 12:57:40 PM | {"source_name":"REFINED_DATA","cut_off_date":"2024-07-23","source_type":"parquet"}                              | REFINED_DATA    |
# | 46 | 02_Migrate_to_staging            | 7/23/2024, 12:40:27 PM | 7/23/2024, 12:57:41 PM | {"source_name":"REFINED_DATA","date":"2024-07-23"}                                                              | REFINED_DATA    |
# | 47 | 01_Generate_paquet               | 7/23/2024, 12:32:49 PM | 7/23/2024, 12:57:42 PM | {"source_name":"REFINED_DATA","date":"2024-07-23"}                                                              | REFINED_DATA    |
# | 48 | 01_Generate_paquet               | 7/23/2024, 10:44:47 AM | 7/23/2024, 10:45:49 AM | {"source_name":"2024-07-23","date":"REFINED_DATA"}                                                              | 2024-07-23      |
# | 49 | 012_Mapping_Json_to_Wisdom       | 7/16/2024, 5:34:24 PM  | 7/16/2024, 11:24:28 PM | {"source_schema_name":"PRE_WISDOM","target_schema_name":"dbo","cut_off_date":"2024-07-16","target_env":"QAS02"} | dbo             |
# | 50 | 011_Mapping_Staging_to_Wisdom    | 7/16/2024, 5:34:24 PM  | 7/16/2024, 10:04:29 PM | {"source_schema_name":"PRE_WISDOM","target_schema_name":"dbo","cut_off_date":"2024-07-16","target_env":"QAS02"} | dbo             |
# | 51 | 01_Mapping_to_Wisdom             | 7/16/2024, 5:34:23 PM  | 7/16/2024, 11:24:29 PM | {"source_schema_name":"PRE_WISDOM","target_schema_name":"dbo","cut_off_date":"2024-07-16","target_env":"QAS02"} | dbo             |
# | 52 | 01_create_delta_table            | 7/16/2024, 4:00:27 PM  | 7/16/2024, 4:43:20 PM  | {"schema_name":"dbo"}                                                                                           | dbo             |
# | 53 | update_delta_query               | 7/16/2024, 3:10:01 PM  | 7/16/2024, 3:10:57 PM  | nan                                                                                                             |                 |
# | 54 | 72_create_temp_table             | 7/16/2024, 2:37:13 PM  | 7/16/2024, 2:45:34 PM  | nan                                                                                                             |                 |
# | 55 | 011_Mapping_Staging_to_Wisdom    | 7/16/2024, 9:56:53 AM  | 7/16/2024, 10:07:33 AM | {"source_schema_name":"PRE_WISDOM","target_schema_name":"dbo","cut_off_date":"2024-07-16","target_env":"QAS02"} | dbo             |
# | 56 | 012_Mapping_Json_to_Wisdom       | 7/16/2024, 9:56:53 AM  | 7/16/2024, 10:40:43 AM | {"source_schema_name":"PRE_WISDOM","target_schema_name":"dbo","cut_off_date":"2024-07-16","target_env":"QAS02"} | dbo             |
# | 57 | 01_Mapping_to_Wisdom             | 7/16/2024, 9:56:51 AM  | 7/16/2024, 10:40:44 AM | {"source_schema_name":"PRE_WISDOM","target_schema_name":"dbo","cut_off_date":"2024-07-16","target_env":"QAS02"} | dbo             |
# | 58 | 01_create_delta_table            | 7/16/2024, 9:14:49 AM  | 7/16/2024, 9:45:15 AM  | {"schema_name":"dbo"}                                                                                           | dbo             |
# | 62 | 02_Migrate_to_staging            | 7/16/2024, 9:14:03 AM  | 7/16/2024, 9:14:44 AM  | {"source_name":"REFINED_DATA","date":"2024-07-15"}                                                              | REFINED_DATA    |
# | 63 | FULL_SYSTEM_DEPLOYMENT_HOT_FIXED | 7/16/2024, 9:14:02 AM  | 7/16/2024, 9:14:46 AM  | {"date":"2024-07-15","target_env":"QAS02","target_schema":"dbo","version_date":"2024-07-15"}                    |                 |
# | 64 | 03_Reconcile_Migration           | 7/16/2024, 9:13:17 AM  | 7/16/2024, 9:13:36 AM  | {"source_name":"WISE_VIEW","cut_off_date":"2024-07-15","source_type":"parquet"}                                 | WISE_VIEW       |
# | 65 | 02_Migrate_to_staging            | 7/16/2024, 9:12:56 AM  | 7/16/2024, 9:13:37 AM  | {"source_name":"WISE_VIEW","date":"2024-07-15"}                                                                 | WISE_VIEW       |
# | 66 | 03_Reconcile_Migration           | 7/16/2024, 9:12:50 AM  | 7/16/2024, 9:13:30 AM  | {"source_name":"REFINED_DATA","cut_off_date":"2024-07-15","source_type":"parquet"}                              | REFINED_DATA    |
# | 67 | 01_Generate_paquet               | 7/16/2024, 9:12:41 AM  | 7/16/2024, 9:13:38 AM  | {"source_name":"WISE_VIEW","date":"2024-07-15"}                                                                 | WISE_VIEW       |
# | 68 | 01_create_delta_table            | 7/16/2024, 12:15:00 AM | 7/16/2024, 12:15:09 AM | {"schema_name":"QAS02"}                                                                                         | QAS02           |
# | 69 | 72_create_temp_table             | 7/15/2024, 11:41:10 PM | 7/15/2024, 11:57:35 PM | nan                                                                                                             |                 |
# | 70 | 03_Reconcile_Migration           | 7/15/2024, 10:40:07 PM | 7/15/2024, 11:05:23 PM | {"source_name":"RGNWISE","cut_off_date":"2024-07-15","source_type":"parquet"}                                   | RGNWISE         |
# | 71 | 02_Migrate_to_staging            | 7/15/2024, 10:26:12 PM | 7/15/2024, 11:05:24 PM | {"source_name":"RGNWISE","date":"2024-07-15"}                                                                   | RGNWISE         |
# | 72 | 01_Generate_paquet               | 7/15/2024, 10:18:50 PM | 7/15/2024, 11:05:25 PM | {"source_name":"RGNWISE","date":"2024-07-15"}                                                                   | RGNWISE         |
# | 73 | 03_Reconcile_Migration           | 7/15/2024, 10:14:45 PM | 7/15/2024, 11:41:03 PM | {"source_name":"WELLVIEW_METRIC","cut_off_date":"2024-07-15","source_type":"parquet"}                           | WELLVIEW_METRIC |
# | 75 | 02_Migrate_to_staging            | 7/15/2024, 9:39:05 PM  | 7/15/2024, 11:41:05 PM | {"source_name":"WELLVIEW_METRIC","date":"2024-07-15"}                                                           | WELLVIEW_METRIC |
# | 76 | 03_Reconcile_Migration           | 7/15/2024, 9:37:57 PM  | 7/15/2024, 11:19:53 PM | {"source_name":"PWED","cut_off_date":"2024-07-15","source_type":"parquet"}                                      | PWED            |
# | 77 | 03_Reconcile_Migration           | 7/15/2024, 9:25:49 PM  | 7/15/2024, 9:52:55 PM  | {"source_name":"WISE","cut_off_date":"2024-07-15","source_type":"parquet"}                                      | WISE            |
# | 78 | 01_Generate_paquet               | 7/15/2024, 9:19:51 PM  | 7/15/2024, 11:41:06 PM | {"source_name":"WELLVIEW_METRIC","date":"2024-07-15"}                                                           | WELLVIEW_METRIC |
# | 79 | 02_Migrate_to_staging            | 7/15/2024, 8:48:03 PM  | 7/15/2024, 9:52:56 PM  | {"source_name":"WISE","date":"2024-07-15"}                                                                      | WISE            |
# | 80 | 02_Migrate_to_staging            | 7/15/2024, 8:45:18 PM  | 7/15/2024, 11:19:54 PM | {"source_name":"PWED","date":"2024-07-15"}                                                                      | PWED            |
# | 81 | 01_Generate_paquet               | 7/15/2024, 8:35:52 PM  | 7/15/2024, 11:19:54 PM | {"source_name":"PWED","date":"2024-07-15"}                                                                      | PWED            |
# | 82 | 01_Generate_paquet               | 7/15/2024, 8:34:11 PM  | 7/15/2024, 9:52:57 PM  | {"source_name":"WISE","date":"2024-07-15"}                                                                      | WISE            |
# | 85 | 02_Migrate_to_staging            | 7/15/2024, 7:37:25 PM  | 7/15/2024, 7:39:26 PM  | {"source_name":"PWED","date":"2024-07-15"}                                                                      | PWED            |
# | 86 | 02_Migrate_to_staging            | 7/15/2024, 7:34:21 PM  | 7/15/2024, 7:39:23 PM  | {"source_name":"RGNWISE","date":"2024-07-15"}                                                                   | RGNWISE         |
# | 87 | 01_Generate_paquet               | 7/15/2024, 7:27:46 PM  | 7/15/2024, 7:39:26 PM  | {"source_name":"PWED","date":"2024-07-15"}                                                                      | PWED            |
# | 88 | 01_Generate_paquet               | 7/15/2024, 7:26:37 PM  | 7/15/2024, 7:39:23 PM  | {"source_name":"RGNWISE","date":"2024-07-15"}                                                                   | RGNWISE         |
# | 91 | 03_Reconcile_Migration           | 7/15/2024, 6:59:15 PM  | 7/15/2024, 7:04:18 PM  | {"source_name":"WISE_VIEW","cut_off_date":"2024-07-15","source_type":"parquet"}                                 | WISE_VIEW       |
# | 92 | 02_Migrate_to_staging            | 7/15/2024, 6:58:58 PM  | 7/15/2024, 7:08:37 PM  | {"source_name":"REFINED_DATA","date":"2024-07-15"}                                                              | REFINED_DATA    |
# | 94 | 02_Migrate_to_staging            | 7/15/2024, 6:49:27 PM  | 7/15/2024, 7:04:19 PM  | {"source_name":"WISE_VIEW","date":"2024-07-15"}                                                                 | WISE_VIEW       |
# | 95 | 01_Generate_paquet               | 7/15/2024, 6:45:35 PM  | 7/15/2024, 7:04:20 PM  | {"source_name":"WISE_VIEW","date":"2024-07-15"}                                                                 | WISE_VIEW       |

# %%
df2 # Overall duration	Cal duration	Date parameter	Type pipeline	Target_env
# Out:
# Empty DataFrame
# Columns: [Pipeline name, Run start, Run end, source_name]
# Index: []

# %%
df2['Run start'] = pd.to_datetime(df2['Run start'], format='%m/%d/%Y, %I:%M:%S %p')
df2['Run end'] = pd.to_datetime(df2['Run end'], format='%m/%d/%Y, %I:%M:%S %p')
df2 = df2[(df2['Run start'] >= '2024-06-05 00:00:00') 
          & (df2['Run start'] < '2024-06-14 00:00:00')
          & (df2['Run end'] >= '2024-05-05 00:00:00') 
          & (df2['Run end'] < '2024-06-14 00:00:00') ]
df2.head()
# Out:
# Empty DataFrame
# Columns: [Pipeline name, Run start, Run end, source_name]
# Index: []

# %%
duration = df2['Run end'].max() - df2['Run start'].min()
hours, remainder = divmod(duration.total_seconds(), 3600)
minutes, _ = divmod(remainder, 60)
print(duration,hours,minutes)
df2['Overall duration'] = f"{int(hours)}h {int(minutes)}m"
# Out:
# 0 days 23:56:05 23.0 56.0

# %%
df2_sorted = df2.loc[df2['source_name'] != 'WISDOM'].sort_values(['source_name', 'Pipeline name'])
df_wd = df2.loc[df2['source_name'] == 'WISDOM'].sort_values(['source_name', 'Pipeline name'])
df2_sorted['Run end'] = np.where(df2_sorted['source_name'] != df2_sorted['source_name'].shift(-1), df2_sorted['Run end'], df2_sorted.groupby('source_name')['Run start'].shift(-1))

def add_minutes(series):
    series.iloc[1:] = series.iloc[1:]
    #+ pd.Timedelta(minutes=2)
    return series

df2_sorted['Run start'] = df2_sorted.groupby('source_name')['Run start'].transform(add_minutes)

# %%
# pd.concat([df2_sorted[['Run start','Run end','source_name']], df2_sorted['source_name'].shift(-1)], axis=1)

# %%
# pd.concat([df2_sorted.groupby('source_name')['Run start'].shift(0), df2_sorted.groupby('source_name')['Run start'].shift(-1)], axis=1)

# %%
df2_sorted['source_name']
# Out:
# 77                 DBO
# 104               PWED
# 103               PWED
# 100               PWED
# 105    WELLVIEW_METRIC
# 101    WELLVIEW_METRIC
# 98     WELLVIEW_METRIC
# 106               WISE
# 102               WISE
# 99                WISE
# 80                 dbo
# 83                 dbo
# 89                 dbo
# 79                 dbo
# 82                 dbo
# 88                 dbo
# 81                 dbo
# 84                 dbo
# 90                 dbo
# 78                 dbo
# 86                 dbo
# 92                 dbo
# Name: source_name, dtype: object

# %%
df2_sorted.reindex(columns=['source_name'])
# Out:
#          source_name
# 77               DBO
# 104             PWED
# 103             PWED
# 100             PWED
# 105  WELLVIEW_METRIC
# 101  WELLVIEW_METRIC
# 98   WELLVIEW_METRIC
# 106             WISE
# 102             WISE
# 99              WISE
# 80               dbo
# 83               dbo
# 89               dbo
# 79               dbo
# 82               dbo
# 88               dbo
# 81               dbo
# 84               dbo
# 90               dbo
# 78               dbo
# 86               dbo
# 92               dbo

# %%
def format_duration(duration):
    hours, remainder = divmod(duration.total_seconds(), 3600)
    minutes, _ = divmod(remainder, 60)
    if int(hours) == 0 :
      return f"{int(minutes)}m"
    elif int(hours) > 0 and int(minutes) == 0 :
      return f"{int(hours)}h"
    else :
      return f"{int(hours)}h {int(minutes)}m"

df2_sorted['Duration'] = (df2_sorted['Run end'] - df2_sorted['Run start']).apply(format_duration)
df_wd['Duration'] = (df_wd['Run end'] - df_wd['Run start']).apply(format_duration)

# %%
df_wd
# Out:
#                     Pipeline name           Run start             Run end
# 94  011_Mapping_Staging_to_Wisdom 2024-06-05 16:18:30 2024-06-05 16:21:11  \
# 93     012_Mapping_Json_to_Wisdom 2024-06-05 16:18:30 2024-06-05 16:41:02
# 95           01_Mapping_to_Wisdom 2024-06-05 16:18:29 2024-06-05 16:44:03
# 97          01_create_delta_table 2024-06-05 13:36:04 2024-06-05 13:44:07
# 85       02_Create_FK_Constraints 2024-06-05 17:56:57 2024-06-05 18:00:17
# 87       02_Create_FK_Constraints 2024-06-05 17:41:12 2024-06-05 17:44:27
# 1              PWED          23h 56m       11m
# 2              PWED          23h 56m       21m
# 3              PWED          23h 56m       15m
# 4   WELLVIEW_METRIC          23h 56m       21m
# 5   WELLVIEW_METRIC          23h 56m       37m
# 6   WELLVIEW_METRIC          23h 56m    1h 14m
# 7              WISE          23h 56m       15m
# 8              WISE          23h 56m       29m
# 9              WISE          23h 56m       27m
# 10              dbo          23h 56m  -16h 27m
# 11              dbo          23h 56m   -1h 26m
# 12              dbo          23h 56m    16h 6m
# 13              dbo          23h 56m   -15h 7m
# 14              dbo          23h 56m   -2h 46m
# 15              dbo          23h 56m    16h 6m
# 16              dbo          23h 56m  -16h 27m
# 17              dbo          23h 56m   -1h 26m
# 18              dbo          23h 56m   16h 24m
# 19              dbo          23h 56m   -16h 6m
# 20              dbo          23h 56m   -2h 48m
# 21              dbo          23h 56m        2m
# 22           WISDOM          23h 56m        2m
# 23           WISDOM          23h 56m       22m
# 24           WISDOM          23h 56m       25m
# 25           WISDOM          23h 56m        8m
# 26           WISDOM          23h 56m        3m
# 27           WISDOM          23h 56m        3m
# 28           WISDOM          23h 56m        3m

# %%
df_combined['Date parameter'] = df_combined['Run start'].dt.date
df_combined = df_combined.rename(columns={'source_name': 'Source name', 'Duration': 'Cal duration'})
df_combined['Type pipeline'] = pd.factorize(df_combined['Pipeline name'])[0]
this_time = pd.Timestamp.now().strftime("%Y-%m-%d_%H-%M-%S")
df_combined.to_csv(f'pipeline_runtime_log_{this_time}.csv', index=False)
df_combined
# Out:
#                     Pipeline name           Run start             Run end
# 0            03_Reconcile_Mapping 2024-06-06 10:18:30 2024-06-06 10:21:49  \
# 1              01_Generate_paquet 2024-06-05 10:26:44 2024-06-05 10:38:26
# 2           02_Migrate_to_staging 2024-06-05 10:38:26 2024-06-05 11:00:19
# 3          03_Reconcile_Migration 2024-06-05 11:00:19 2024-06-05 11:15:49
# 4              01_Generate_paquet 2024-06-05 10:26:12 2024-06-05 10:48:04
# 5           02_Migrate_to_staging 2024-06-05 10:48:04 2024-06-05 11:25:23
# 6          03_Reconcile_Migration 2024-06-05 11:25:23 2024-06-05 12:39:24
# 7              01_Generate_paquet 2024-06-05 10:25:44 2024-06-05 10:41:09
# 8           02_Migrate_to_staging 2024-06-05 10:41:09 2024-06-05 11:11:03
# 9          03_Reconcile_Migration 2024-06-05 11:11:03 2024-06-05 11:38:17
# 10  011_Mapping_Staging_to_Wisdom 2024-06-06 09:32:06 2024-06-05 17:59:28
# 11  011_Mapping_Staging_to_Wisdom 2024-06-05 17:59:28 2024-06-05 17:25:43
# 12  011_Mapping_Staging_to_Wisdom 2024-06-05 17:25:43 2024-06-06 09:32:06
# 13     012_Mapping_Json_to_Wisdom 2024-06-06 09:32:06 2024-06-05 18:39:12
# 14     012_Mapping_Json_to_Wisdom 2024-06-05 18:39:12 2024-06-05 17:25:43
# 15     012_Mapping_Json_to_Wisdom 2024-06-05 17:25:43 2024-06-06 09:32:05
# 16           01_Mapping_to_Wisdom 2024-06-06 09:32:05 2024-06-05 17:59:27
